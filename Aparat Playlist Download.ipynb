# %%
# !pip3 install tqdm requests beautifulsoup4 selenium webdriver_manager

# %%
import os
import re
import string
import time
from tqdm.notebook import tqdm
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.microsoft import EdgeChromiumDriverManager

# %% [markdown]
# # Set URL

# %%
playlist = 822473
URL = f"https://www.aparat.com/playlist/{playlist}"

# %% [markdown]
# # Get Page

# %%
def get_soup(URL, driver='Chrome'):
    if driver=='Chrome':   
        driver = webdriver.Chrome(ChromeDriverManager().install())
    elif driver=='Firefox':
        driver = webdriver.Firefox(GeckoDriverManager().install())
    elif driver=='Edge':
        driver = webdriver.Edge(EdgeChromiumDriverManager().install())
    
    driver.get(URL)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")    
    return soup
#
soup = get_soup(URL, driver='Edge')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache

# %% [markdown]
# # Create Folder

# %%
title = soup.find('div', attrs={'class': 'playlist-field'}).get_text()
path = 'F:\\Video_DL\\' + title

try:
    os.makedirs(path)
    print(path)
    print('This folder is created')
except:
    print(path)
    print('This folder is exist')

#    
os.chdir(path)
# Out:
# F:\Video_DL\وبینارهای کاربردی
# This folder is created

# %% [markdown]
# # Downlaod Courses

# %%
download_urls = []
playlist_items = soup.find_all('li', attrs={'class': 'playlist-item'})

x = "۰۱۲۳۴۵۶۷۸۹"
y = "0123456789"
table_digit = str.maketrans(x, y)
table_punctuation = str.maketrans(string.punctuation, '_'*len(string.punctuation))

with tqdm(total  =len(playlist_items)) as pbar:
    for index, a in enumerate(playlist_items):
        isok = True
        while isok:
            try:
                a_tag = a.find('div', attrs={'class': 'thumb-content'}).find('a', href=True, text=True)
                item_url = 'https://www.aparat.com' + a_tag['href']
                item_title = a_tag.get_text()
                print(item_title)
                
                file_name = str(index+1) + '_' + item_title.translate(table_punctuation)              
                file_name = file_name.translate(table_digit) + '.mp4'                              
                   
                if os.path.exists(file_name)==False:
                    item_soup = get_soup(item_url, driver='Edge')
                    file_url = item_soup.find("meta", property="og:video")['content']

                    print(file_name)
                    print(file_url)

                    download_urls.append(file_url)
                    r = requests.get(file_url, stream = True) 
                    
                    os.chdir(path)
                    with open(file_name,"wb") as video: 
                        for chunk in r.iter_content(chunk_size=1024):         
                            if chunk: 
                                video.write(chunk) 
                isok = False
            except :
                print('Error')
                isok = True
        pbar.update(1)
# Out:
#   0%|          | 0/23 [00:18<?, ?it/s]
# وبینار علوم داده در صنعت بانکداری
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار علوم داده در صنعت بانکداری
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 1_وبینار علوم داده در صنعت بانکداری.mp4
# https://aspb26.asset.aparat.com/aparat-video/ba68f4aad42aa84ac1a0449c23b1d2b331125207-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjYwMWU2M2RjMzU0MjMyNWE2OTM5MmFkN2FhM2ViMGUwIiwiZXhwIjoxNjU3Mzk2ODUwLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.4-4g7F9tKdTzx97r47QrNp5ymRM-KWAdj_7IXhkDsHA
# وبینار چالش‌های تیم داده الوپیک
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار چالش‌های تیم داده الوپیک
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار چالش‌های تیم داده الوپیک
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 2_وبینار چالش‌های تیم داده الوپیک.mp4
# https://aspb20.asset.aparat.com/aparat-video/03fec05550e506b0dd96cc5902470ee329854294-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImUxZDFmYmQyN2E4OTNlZjVjNWNkYzliMWU3OTEzNGEzIiwiZXhwIjoxNjU3Mzk3NDg1LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.t0-yCs6zIKwM9OIZpSXiF9beHHt0PRe0H7TrISrOWgY
# وبینار سیستم توصیه گر یکتانت (ریکامندیشن سیستم یکتانت)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 3_وبینار سیستم توصیه گر یکتانت _ریکامندیشن سیستم یکتانت_.mp4
# https://aspb25.asset.aparat.com/aparat-video/1ddb034ab597bc682bd78dc79a07ec1731136720-480p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImQ0NzJlNDgxNzlhZDc1ZGNkM2Q2Yjg4MTc0OTczOTAxIiwiZXhwIjoxNjU3Mzk3NzI2LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.m9WGasDxaO6B3SCLVeMugb3DkTR6Tcis7NKPWTUrCQM
# وبینار  پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش اول)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار  پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش اول)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 4_وبینار  پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین _بخش اول_.mp4
# https://aspb35.asset.aparat.com/aparat-video/b08668c334574a961afdec681ffd19e535294262-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImY0YjdmZGZiNTAwMWQ2YmU2Yzg5Njg2OWVhYTNjMDM4IiwiZXhwIjoxNjU3Mzk3OTQ2LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.WDlEX3IE8BHMehQIF11FGWDs3bq4ijEVq7rh794DgRc
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین (بخش دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 5_وبینار پیش بینی بازار های مالی از تحلیل تکنیکال تا یادگیری ماشین _بخش دوم_.mp4
# https://aspb31.asset.aparat.com/aparat-video/5c5f4cb3559f0783a75c75883fc079e135294556-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjUxZjdlNjE5MGEyOGEwN2E2YmFmNWI0NTY3ZDY5MTY2IiwiZXhwIjoxNjU3NDAwMTUyLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.FB5OUbcEgWV3kpFk70aG0vkaC0HSIQxiLh9xYCwAoT4
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت دوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 6_وبینار مسیر تبدیل شدن به یک متخصص داده _قسمت دوم_.mp4
# https://aspb30.asset.aparat.com/aparat-video/6deaf02dc51b2fb1db7db475770565c937804209-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjViYTFkNjhhYWNhMzk5MjNiMTg1NTdjYjg1M2FhOTU1IiwiZXhwIjoxNjU3NDAwNzE1LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.GwkyCSTM9Ci-l0PnrHrQJS5A3mrpjs0MbfJbmsDZYCA
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت سوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت سوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص داده (قسمت سوم)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 7_وبینار مسیر تبدیل شدن به یک متخصص داده _قسمت سوم_.mp4
# https://aspb28.asset.aparat.com/aparat-video/260f8d6e0d1130807527c637014c401337804743-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjNjYTE3ZWFjNjgxMjgzNWVjNGQzMDA3YmZjYzFlMDM1IiwiZXhwIjoxNjU3NDAwOTUwLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.D8lVPiVcAyN9hq-Fl8E5PugO0b9j3N8n55ytAAFPcIQ
# وبینار مسیر تبدیل شدن به یک متخصص علم داده (قسمت اول)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار مسیر تبدیل شدن به یک متخصص علم داده (قسمت اول)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 8_وبینار مسیر تبدیل شدن به یک متخصص علم داده _قسمت اول_.mp4
# https://aspb30.asset.aparat.com/aparat-video/c4de3af9f11abd8b5c7c49b18dca2dc737821870-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjA3Nzc2OTg5YjgyZWIxYjNiODg2NWZjMWNlNDI0ZDE5IiwiZXhwIjoxNjU3NDAxMTk3LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.3nrcUhvugTscIE8ViSkvS1jXY0rAIqNWXZTjyoENNXk
# وبینار اول : مقدمه ای بر هوش کسب و کار و ابزارهای مطرح آن
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 9_وبینار اول _ مقدمه ای بر هوش کسب و کار و ابزارهای مطرح آن.mp4
# https://aspb36.asset.aparat.com/aparat-video/42351a7c508d6189ac8c3750658aa3a939070056-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImY5OWYxMmQzMjM2MWY3NWRmY2MwODBkYTU2NWQxZDNhIiwiZXhwIjoxNjU3NDAxMzQ3LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.FBubuR2ENYu08QEf7JgL8RelGqfEs6GBV9G-YF5Up3E
# وبینار چهارم : هوش کسب و کار با ابزار Power BI
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 10_وبینار چهارم _ هوش کسب و کار با ابزار Power BI.mp4
# https://hajifirouz2.asset.aparat.com/aparat-video/6f9ae0eadb31efca4d083da13af7231240242287-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjI4YTQzN2ZiOTc3ODk3NzRmZDYwYzBkNmZlN2VmNjMxIiwiZXhwIjoxNjU3NDAxNTQ0LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.oWxP2IqJOzdiELC9_wVwZhW41ljt-9dRmeM8zwiSBp0
# وبینار پنجم : هوش کسب و کار با ابزار Tableau
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 11_وبینار پنجم _ هوش کسب و کار با ابزار Tableau.mp4
# https://hajifirouz12.asset.aparat.com/aparat-video/da30590bd9462c6115f662d1c77bd59a40386298-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImYyNTlmOGQyODRmYTUzNDAwMmZkYWQ4NjU2Y2IzYmI1IiwiZXhwIjoxNjU3NDAxODI0LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.fJCsS9BNhkUrfrr3x78BD6UBCJqhDc7JBpgV-3iRJKA
# وبینار نهم : ارتباط تحلیل کسب و کار BA ، هوش کسب و کار BI
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 12_وبینار نهم _ ارتباط تحلیل کسب و کار BA ، هوش کسب و کار BI.mp4
# https://hajifirouz8.asset.aparat.com/aparat-video/136dcdeb0ed49a19095037da9583d9c242514453-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjMyMzAwMzZjZDE1ZjE3MDA2NTg2NmM5YTRkZDg1ODlkIiwiZXhwIjoxNjU3NDAyMDY5LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.eHOUVH-bGYaApH6M9UZ1kkoZAMWEvkJdc6Fs8800wUY
# وبینار دوم : راهکارهای اوراکل در هوش کسب‌وکار
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 13_وبینار دوم _ راهکارهای اوراکل در هوش کسب‌وکار.mp4
# https://caspian3.asset.aparat.com/aparat-video/abab79544f3b642927d76bf04a16445f43366532-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImNiMjA0MWMzZWRkYzc1NWM3ZjM5NGViY2M5MDFlZmRlIiwiZXhwIjoxNjU3NDAyMjcxLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.TMc7XNonChKEzVBI4SXq1yFLpF4k8d0Ww-7UZhX2GRs
# وبینار سوم : راهکارهای میکروسافت در هوش کسب و کار و معرفی Power BI
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 14_وبینار سوم _ راهکارهای میکروسافت در هوش کسب و کار و معرفی Power BI.mp4
# https://persian5.asset.aparat.com/aparat-video/2bf0507ff8cb918585507dee5705e37c43430165-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6Ijc2OTQ4YWVjOGE0ZjgyNTk0YTMzOTkwMzA4MjRiYTYwIiwiZXhwIjoxNjU3NDAyNTE4LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.dpJQnoDmPXg-KKRJs0WHrXDzwT_h0IM1P1UIhtyf9I4
# وبینار ششم : هوش کسب‌وکار با ابزار QlickView
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 15_وبینار ششم _ هوش کسب‌وکار با ابزار QlickView.mp4
# https://caspian5.asset.aparat.com/aparat-video/b42bf2f86bf12aaf0ed1ab4c04fa318a43943668-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjZiNTFhZWQ2NzIyZmZiYTcxOTVmNzM3MWYzNGNjY2Q1IiwiZXhwIjoxNjU3NDAyNjc5LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.h04FBp2Mk_ohldhdpuiKu7Z7DkBYz0cdiEfjgsoDV1k
# وبینار هشتم : تحلیلگری داده، رویکرد نوین مدیریت
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 16_وبینار هشتم _ تحلیلگری داده، رویکرد نوین مدیریت.mp4
# https://persian5.asset.aparat.com/aparat-video/37a0aff2eadc347f035cc79a680c448743943761-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjI5Y2RhM2Y5ZmFlZDYxOGRjYzZjNDRlNmY3ODNmYTQ5IiwiZXhwIjoxNjU3NDAyOTM1LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.v1OR84SptY9UvO5RzIWj-RpjWO4i5Nr-Y2tD6dTrJHE
# وبینار هفتم : مباحث پیشرفته در هوش کسب‌وکار
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 17_وبینار هفتم _ مباحث پیشرفته در هوش کسب‌وکار.mp4
# https://persian1.asset.aparat.com/aparat-video/945f4539feeb0cf5fa331a231ac503e543943865-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImJiNmU3Y2M2NmQxNDA3MWY0YTcxNTAzM2U1NDc2YmEwIiwiZXhwIjoxNjU3NDAzMTQ2LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.hMUdvu5kO-QMiXk5fByggSpWlab6xixxgHGOOXJJOt8
# وبینار دهم : هوش کسب‌وکار و راهکارهای مدیریت داده‌ در سازمان‌ها
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار دهم : هوش کسب‌وکار و راهکارهای مدیریت داده‌ در سازمان‌ها
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار دهم : هوش کسب‌وکار و راهکارهای مدیریت داده‌ در سازمان‌ها
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 18_وبینار دهم _ هوش کسب‌وکار و راهکارهای مدیریت داده‌ در سازمان‌ها.mp4
# https://caspian3.asset.aparat.com/aparat-video/704404adbc586a2fd60a1ebf5ca16d0543943915-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImMyM2JjY2EyZmI0ZDk5YzhiYzE2OGUwN2ExMjQxOWQzIiwiZXhwIjoxNjU3NDAzNjIxLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.xYMBfmBIsVJEfh_4QxV-IGaE4dNoMHl6_h3PpZUQ878
# وبینار یازدهم : هوش کسب و کار و مدیریت پروژه
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 19_وبینار یازدهم _ هوش کسب و کار و مدیریت پروژه.mp4
# https://persian1.asset.aparat.com/aparat-video/809b564bed56799864e3849ed48d228443943960-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6Ijg4YmE3YTg2NTljMDYxNjkwMTcwMDY0NDg3NDk5ZTMzIiwiZXhwIjoxNjU3NDAzOTIzLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.rcXVjPuMMIuSIBqpUpK8RdkCGWfnchQ4Vqy_GrDLcR4
# وبینار دوازدهم : هوش کسب‌وکار در مدیریت مالی
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار دوازدهم : هوش کسب‌وکار در مدیریت مالی
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# Error
# وبینار دوازدهم : هوش کسب‌وکار در مدیریت مالی
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 20_وبینار دوازدهم _ هوش کسب‌وکار در مدیریت مالی.mp4
# https://persian3.asset.aparat.com/aparat-video/7bf928a861c607f3109aff055ee157ed43969030-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImUwMmQyM2VlMWY2YTRjMmQwZDY2NjA4MDFhYTY2ODJhIiwiZXhwIjoxNjU3NDA0NDAwLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.2-40JE4GaaCSuf6qSBA5vDsmVtJ2gf_RTVRQbkoQPYk
# وبینار سیزدهم : هوش کسب‌وکار در مدیریت منابع
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 21_وبینار سیزدهم _ هوش کسب‌وکار در مدیریت منابع.mp4
# https://persian4.asset.aparat.com/aparat-video/5281005759c5d3c8057c5350822bfc9043969076-1080p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6ImM1NTljMDVkYjMzN2NhOWE1ZjQzYjc1MmMwNWY4NDlmIiwiZXhwIjoxNjU3NDA0NTcwLCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.QZqjxjQsw3cF2VjAVbWhlnrv6cl6gdniV9F1Ny2Kf7Y
# وبینار چهاردهم : هوش کسب‌وکار در مدیریت ریسک
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 22_وبینار چهاردهم _ هوش کسب‌وکار در مدیریت ریسک.mp4
# https://caspian2.asset.aparat.com/aparat-video/eefc7945de41ef7156cfffa6edfef91944068751-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjIzZDYxOTAxYTRmMjQwNzllOWZjNzdkMjA3OGJhOGJhIiwiZXhwIjoxNjU3NDA0NzM5LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.1voaZFiapiKY4YXOnmOQOwIymREd8Hi_b4AEm9xlO0M
# وبینار پانزدهم : هوش کسب‌وکار در حوزه تحلیل اطلاعات مکانی GIS
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current edge version is 103.0.1264
# [WDM] - Get LATEST edgedriver version for 103.0.1264 Edge
# [WDM] - Driver [C:\Users\TC\.wdm\drivers\edgedriver\win64\103.0.1264.49\msedgedriver.exe] found in cache
# 23_وبینار پانزدهم _ هوش کسب‌وکار در حوزه تحلیل اطلاعات مکانی GIS.mp4
# https://persian3.asset.aparat.com/aparat-video/e051bd9f3fb6fcff0a91bcc15581c18644068875-720p.apt?wmsAuthSign=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbiI6IjA2YzliMjgzMjdiYWU1NTE5ZmZjNTc3YTQ5NjRlMDA4IiwiZXhwIjoxNjU3NDA0OTY2LCJpc3MiOiJTYWJhIElkZWEgR1NJRyJ9.ya7vXnDOItkZvSwuh6922v0xtrIrNS1G-FLatMLEhzc
